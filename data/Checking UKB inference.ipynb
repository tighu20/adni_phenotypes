# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
disease_info_df = pd.read_csv('ukb_diagnosis.csv', index_col=0)
disease_info_df.shape
# Out:
# (5720, 1)

# %%
np.unique(disease_info_df['diag_icd10'], return_counts=True)
# Out:
# (array(['AD', 'PD', 'PSP'], dtype=object), array([2537, 3070,  113]))

# %%
all_resutls_df = pd.read_csv('../results/latest_output.csv', index_col=0)
all_resutls_df
# Out:
#              mean       std
# ukb_id
# 1000028  0.274051  0.238850
# 1000118  0.176027  0.166102
# 1000133  0.105183  0.132620
# 1000196  0.443064  0.289957
# 1000211  0.138353  0.165453
# ...           ...       ...
# 6025771  0.053418  0.047157
# 6025805  0.157301  0.164484
# 6025843  0.118969  0.114440
# 6025850  0.351324  0.220100
# 6025942  0.059597  0.081068
#
# [37967 rows x 2 columns]

# %%
joined_df = all_resutls_df.join(disease_info_df, how='inner')
joined_df
# Out:
#              mean       std diag_icd10
# 1174643  0.843564  0.169936         AD
# 1383275  0.737736  0.246617         AD
# 1459613  0.319657  0.247103         PD
# 1471348  0.616532  0.231237         AD
# 1492760  0.257692  0.174875         PD
# ...           ...       ...        ...
# 5723283  0.350436  0.257641         PD
# 5765412  0.155502  0.191292         PD
# 5819854  0.211619  0.199444         PD
# 5821545  0.727666  0.236419         AD
# 5892488  0.243954  0.195773         PD
#
# [66 rows x 3 columns]

# %%
np.unique(joined_df.diag_icd10, return_counts=True)
# Out:
# (array(['AD', 'PD'], dtype=object), array([14, 52]))

# %%
joined_df[joined_df.index.isin(joined_df.index[joined_df.index.duplicated()].unique())]
# Out:
#              mean       std diag_icd10
# 2718684  0.739687  0.256052         PD
# 2718684  0.739687  0.256052         AD

# %%
joined_df[joined_df.diag_icd10 == 'AD'].describe()
# Out:
#             mean        std
# count  14.000000  14.000000
# mean    0.619103   0.194407
# std     0.283588   0.063330
# min     0.090066   0.082295
# 25%     0.553692   0.134474
# 50%     0.732701   0.218047
# 75%     0.799580   0.243280
# max     0.933827   0.269960

# %%
joined_df[joined_df.diag_icd10 == 'PD'].describe()
# Out:
#             mean        std
# count  52.000000  52.000000
# mean    0.235877   0.183608
# std     0.165007   0.062417
# min     0.042014   0.050500
# 25%     0.119667   0.139571
# 50%     0.177493   0.183988
# 75%     0.318505   0.228683
# max     0.739687   0.308911

# %%
joined_df[joined_df.diag_icd10 == 'AD'].sort_values(by='mean')
# Out:
#              mean       std diag_icd10
# 2511898  0.090066  0.099041         AD
# 1971804  0.091417  0.122653         AD
# 1502601  0.256988  0.205914         AD
# 1878467  0.553134  0.269960         AD
# 5276835  0.555365  0.245567         AD
# 1471348  0.616532  0.231237         AD
# 5821545  0.727666  0.236419         AD
# 1383275  0.737736  0.246617         AD
# 2718684  0.739687  0.256052         AD
# 4652621  0.795463  0.230180         AD
# 5382091  0.800952  0.203898         AD
# 1174643  0.843564  0.169936         AD
# 4747402  0.925043  0.082295         AD
# 4199832  0.933827  0.121932         AD

# %%
joined_df[joined_df.diag_icd10 == 'PD'].sort_values(by='mean', ascending=False)
# Out:
#              mean       std diag_icd10
# 2718684  0.739687  0.256052         PD
# 3769669  0.671909  0.225386         PD
# 3318498  0.605472  0.295517         PD
# 2275507  0.593884  0.276053         PD
# 3047828  0.532650  0.265175         PD
# 5018170  0.499279  0.308911         PD
# 1733101  0.421165  0.302007         PD
# 1901760  0.369827  0.264232         PD
# 3204408  0.358288  0.251676         PD
# 5723283  0.350436  0.257641         PD
# 2357487  0.330120  0.238575         PD
# 3549084  0.329751  0.204532         PD
# 1459613  0.319657  0.247103         PD
# 2013553  0.318121  0.249622         PD
# 2135605  0.301048  0.208516         PD
# 4061219  0.276794  0.262605         PD
# 1492760  0.257692  0.174875         PD
# 5892488  0.243954  0.195773         PD
# 2631110  0.233688  0.222177         PD
# 3542965  0.233015  0.195074         PD
# 4282606  0.221761  0.187938         PD
# 2564316  0.214452  0.161373         PD
# 5819854  0.211619  0.199444         PD
# 3342836  0.202711  0.180038         PD
# 1617724  0.182135  0.204919         PD
# 4184804  0.179787  0.199233         PD
# 5317140  0.175198  0.153172         PD
# 1532621  0.171481  0.192271         PD
# 5686483  0.169389  0.194182         PD
# 3033122  0.160846  0.172498         PD
# 5765412  0.155502  0.191292         PD
# 2917693  0.150899  0.161398         PD
# 2631191  0.145781  0.173310         PD
# 3207251  0.145058  0.134070         PD
# 3696225  0.142804  0.142924         PD
# 4804137  0.137105  0.161644         PD
# 5036109  0.136377  0.139593         PD
# 4991507  0.128150  0.153814         PD
# 4265867  0.121018  0.140142         PD
# 2292257  0.115615  0.145569         PD
# 2491460  0.107576  0.139506         PD
# 2861715  0.106045  0.139266         PD
# 2869750  0.099090  0.109586         PD
# 2106457  0.098314  0.105048         PD
# 1925689  0.097781  0.137158         PD
# 3157620  0.088750  0.118738         PD
# 4912605  0.084475  0.093509         PD
# 3273184  0.082918  0.111570         PD
# 3575461  0.075202  0.098697         PD
# 5502509  0.074170  0.079660         PD
# 4654041  0.055142  0.074070         PD
# 1816255  0.042014  0.050500         PD

# %%
all_data = [joined_df[joined_df.diag_icd10 == 'AD']['mean'].values, 
           joined_df[joined_df.diag_icd10 == 'AD']['std'].values,
           joined_df[joined_df.diag_icd10 == 'PD']['mean'].values,
           joined_df[joined_df.diag_icd10 == 'PD']['std'].values]


_ = plt.boxplot(all_data, labels=['AD mean', 'AD std', 'PD mean', 'PD std'])

# %%
print(all_resutls_df.shape)
print(joined_df.shape)
print(all_resutls_df[~all_resutls_df.index.isin(joined_df.index)].shape)
print()
print(len(set(joined_df.index.values)))
# Out:
# (37967, 2)
# (66, 3)
# (37902, 2)
#
# 65

# %%
only_controls = all_resutls_df[~all_resutls_df.index.isin(joined_df.index)]
_ = plt.boxplot([only_controls['mean'], only_controls['std']], labels=['Controls mean', 'Controls std'])

#display(only_controls[only_controls['mean'] > 0.9].sort_values(by='std'))
display(only_controls[only_controls['mean'] > 0.5].sort_values(by='std'))
# Out:
#              mean       std
# ukb_id
# 1081961  0.974033  0.027074
# 4522720  0.966791  0.031580
# 5399218  0.954702  0.034964
# 4092276  0.963893  0.035627
# 3938984  0.965427  0.048066
# ...           ...       ...
# 1987507  0.584810  0.313969
# 2769754  0.520035  0.314825
# 4421326  0.525545  0.317138
# 5701868  0.511868  0.322570
# 1334088  0.535662  0.325527
#
# [1298 rows x 2 columns]

# %%
joined_df[(joined_df.diag_icd10 == 'AD') & (joined_df['mean'] > 0.5)]
# Out:
#              mean       std diag_icd10
# 1174643  0.843564  0.169936         AD
# 1383275  0.737736  0.246617         AD
# 1471348  0.616532  0.231237         AD
# 1878467  0.553134  0.269960         AD
# 2718684  0.739687  0.256052         AD
# 4199832  0.933827  0.121932         AD
# 4652621  0.795463  0.230180         AD
# 4747402  0.925043  0.082295         AD
# 5276835  0.555365  0.245567         AD
# 5382091  0.800952  0.203898         AD
# 5821545  0.727666  0.236419         AD

# %%
all_resutls_df[(all_resutls_df['mean'] > 0.5) & (all_resutls_df['std'] < 0.05)]
# Out:
#              mean       std
# ukb_id
# 1081961  0.974033  0.027074
# 3938984  0.965427  0.048066
# 4092276  0.963893  0.035627
# 4522720  0.966791  0.031580
# 5399218  0.954702  0.034964
