# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
#demo_cols = ['diagnosis', 'age', 'gender', 'eTIV']

features_cort = ['thickness_bankssts_lh',  'thickness_caudalanteriorcingulate_lh', 'thickness_caudalmiddlefrontal_lh',  'thickness_cuneus_lh',  'thickness_entorhinal_lh',  'thickness_fusiform_lh',  'thickness_inferiorparietal_lh',  'thickness_inferiortemporal_lh',  'thickness_isthmuscingulate_lh',  'thickness_lateraloccipital_lh',  'thickness_lateralorbitofrontal_lh',  'thickness_lingual_lh',  'thickness_medialorbitofrontal_lh',  'thickness_middletemporal_lh',  'thickness_parahippocampal_lh',  'thickness_paracentral_lh',  'thickness_parsopercularis_lh',  'thickness_parsorbitalis_lh',  'thickness_parstriangularis_lh',  'thickness_pericalcarine_lh',  'thickness_postcentral_lh',  'thickness_posteriorcingulate_lh',  'thickness_precentral_lh',  'thickness_precuneus_lh',  'thickness_rostralanteriorcingulate_lh', 'thickness_rostralmiddlefrontal_lh',  'thickness_superiorfrontal_lh',  'thickness_superiorparietal_lh',  'thickness_superiortemporal_lh',  'thickness_supramarginal_lh',  'thickness_frontalpole_lh',  'thickness_temporalpole_lh',  'thickness_transversetemporal_lh',  'thickness_insula_lh',  'thickness_bankssts_rh',  'thickness_caudalanteriorcingulate_rh', 'thickness_caudalmiddlefrontal_rh',  'thickness_cuneus_rh',  'thickness_entorhinal_rh',  'thickness_fusiform_rh',  'thickness_inferiorparietal_rh',  'thickness_inferiortemporal_rh',  'thickness_isthmuscingulate_rh',  'thickness_lateraloccipital_rh',  'thickness_lateralorbitofrontal_rh',  'thickness_lingual_rh',  'thickness_medialorbitofrontal_rh',  'thickness_middletemporal_rh',  'thickness_parahippocampal_rh',  'thickness_paracentral_rh',  'thickness_parsopercularis_rh',  'thickness_parsorbitalis_rh',  'thickness_parstriangularis_rh',  'thickness_pericalcarine_rh',  'thickness_postcentral_rh',  'thickness_posteriorcingulate_rh',  'thickness_precentral_rh',  'thickness_precuneus_rh',  'thickness_rostralanteriorcingulate_rh', 'thickness_rostralmiddlefrontal_rh',  'thickness_superiorfrontal_rh',  'thickness_superiorparietal_rh',  'thickness_superiortemporal_rh',  'thickness_supramarginal_rh',  'thickness_frontalpole_rh',  'thickness_temporalpole_rh',  'thickness_transversetemporal_rh',  'thickness_insula_rh']

features_vol = ['volume_bankssts_lh', 'volume_caudalanteriorcingulate_lh', 'volume_caudalmiddlefrontal_lh', 'volume_cuneus_lh', 'volume_entorhinal_lh', 'volume_fusiform_lh', 'volume_inferiorparietal_lh', 'volume_inferiortemporal_lh', 'volume_isthmuscingulate_lh', 'volume_lateraloccipital_lh', 'volume_lateralorbitofrontal_lh', 'volume_lingual_lh', 'volume_medialorbitofrontal_lh', 'volume_middletemporal_lh', 'volume_parahippocampal_lh', 'volume_paracentral_lh', 'volume_parsopercularis_lh', 'volume_parsorbitalis_lh', 'volume_parstriangularis_lh', 'volume_pericalcarine_lh', 'volume_postcentral_lh', 'volume_posteriorcingulate_lh', 'volume_precentral_lh', 'volume_precuneus_lh', 'volume_rostralanteriorcingulate_lh', 'volume_rostralmiddlefrontal_lh', 'volume_superiorfrontal_lh', 'volume_superiorparietal_lh', 'volume_superiortemporal_lh', 'volume_supramarginal_lh', 'volume_frontalpole_lh', 'volume_temporalpole_lh', 'volume_transversetemporal_lh', 'volume_insula_lh', 'volume_bankssts_rh', 'volume_caudalanteriorcingulate_rh', 'volume_caudalmiddlefrontal_rh', 'volume_cuneus_rh', 'volume_entorhinal_rh', 'volume_fusiform_rh', 'volume_inferiorparietal_rh', 'volume_inferiortemporal_rh', 'volume_isthmuscingulate_rh', 'volume_lateraloccipital_rh', 'volume_lateralorbitofrontal_rh', 'volume_lingual_rh', 'volume_medialorbitofrontal_rh', 'volume_middletemporal_rh', 'volume_parahippocampal_rh', 'volume_paracentral_rh', 'volume_parsopercularis_rh', 'volume_parsorbitalis_rh', 'volume_parstriangularis_rh', 'volume_pericalcarine_rh', 'volume_postcentral_rh', 'volume_posteriorcingulate_rh', 'volume_precentral_rh', 'volume_precuneus_rh', 'volume_rostralanteriorcingulate_rh', 'volume_rostralmiddlefrontal_rh', 'volume_superiorfrontal_rh', 'volume_superiorparietal_rh', 'volume_superiortemporal_rh', 'volume_supramarginal_rh', 'volume_frontalpole_rh', 'volume_temporalpole_rh', 'volume_transversetemporal_rh', 'volume_insula_rh']

features_vol_extra = ['volume_Left-Cerebellum-White-Matter', 'volume_Left-Cerebellum-Cortex',
                      'volume_Left-Thalamus-Proper', 'volume_Left-Caudate', 'volume_Left-Putamen',
                      'volume_Left-Pallidum','volume_Brain-Stem', 'volume_Left-Hippocampus', 
                      'volume_Left-Amygdala', 'volume_Left-Accumbens-area', 'volume_Right-Cerebellum-White-Matter',
                      'volume_Right-Cerebellum-Cortex', 'volume_Right-Thalamus-Proper', 'volume_Right-Caudate',
                      'volume_Right-Putamen', 'volume_Right-Pallidum', 'volume_Right-Hippocampus', 
                      'volume_Right-Amygdala', 'volume_Right-Accumbens-area']

# %%
nacc_df = pd.read_csv('nacc_collatedResults.csv', sep='\t', index_col=0)
nacc_df
# Out:
#                                                         diagnosis  \
# subj
# sub-NACC000034                           Alzheimer’s disease (AD)
# sub-NACC000225  Vascular brain injury or vascular dementia inc...
# sub-NACC000511                           Alzheimer’s disease (AD)
# sub-NACC000531                            Lewy body disease (LBD)
# sub-NACC000920                                            Control
# ...                                                           ...
# sub-NACC999546                                            Control
# sub-NACC999566                                         Depression
# sub-NACC999724                       Traumatic brain injury (TBI)
# sub-NACC999780                                    Missing/unknown
# sub-NACC999854                                            Control
#
#                 session_diff  age  gender          eTIV  nacmmse  digif  \
# subj
# sub-NACC000034           291   81  Female  1.428260e+06      NaN    NaN
# sub-NACC000225             0   77    Male  1.461785e+06     24.0    4.0
# sub-NACC000511           335   77  Female  1.584573e+06      NaN    NaN
# sub-NACC000531           334   62    Male  1.824642e+06      NaN    NaN
# sub-NACC000920           572   64  Female  1.449166e+06      NaN    NaN
# ...                      ...  ...     ...           ...      ...    ...
# sub-NACC999546           420   78    Male  1.478121e+06      NaN    NaN
# sub-NACC999566            30   53  Female  1.197214e+06      NaN    NaN
# sub-NACC999724            26   50    Male  1.348062e+06      NaN    NaN
# sub-NACC999780             0   81    Male  1.831828e+06     29.0    7.0
# sub-NACC999854           271   80  Female  1.282693e+06      NaN    NaN
#
#                 digib  animals  trialsb  ...  volume_Right-WM-hypointensities  \
# subj                                     ...
# sub-NACC000034    NaN      NaN      NaN  ...                                0
# sub-NACC000225    5.0     19.0      NaN  ...                                0
# sub-NACC000511    NaN      NaN      NaN  ...                                0
# sub-NACC000531    NaN      NaN      NaN  ...                                0
# sub-NACC000920    NaN      NaN      NaN  ...                                0
# ...               ...      ...      ...  ...                              ...
# sub-NACC999546    NaN      NaN      NaN  ...                                0
# sub-NACC999566    NaN      NaN      NaN  ...                                0
# sub-NACC999724    NaN      NaN      NaN  ...                                0
# sub-NACC999780    4.0     17.0    115.0  ...                                0
# sub-NACC999854    NaN      NaN      NaN  ...                                0
#
#                 volume_non-WM-hypointensities  \
# subj
# sub-NACC000034                            0.0
# sub-NACC000225                            0.0
# sub-NACC000511                            0.0
# sub-NACC000531                            0.0
# sub-NACC000920                            0.0
# ...                                       ...
# sub-NACC999546                            0.0
# sub-NACC999566                            0.0
# sub-NACC999724                            0.0
# sub-NACC999780                            0.0
# sub-NACC999854                            0.0
#
#                 volume_Left-non-WM-hypointensities  \
# subj
# sub-NACC000034                                   0
# sub-NACC000225                                   0
# sub-NACC000511                                   0
# sub-NACC000531                                   0
# sub-NACC000920                                   0
# ...                                            ...
# sub-NACC999546                                   0
# sub-NACC999566                                   0
# sub-NACC999724                                   0
# sub-NACC999780                                   0
# sub-NACC999854                                   0
#
#                 volume_Right-non-WM-hypointensities  volume_Optic-Chiasm  \
# subj
# sub-NACC000034                                    0                232.3
# sub-NACC000225                                    0                183.9
# sub-NACC000511                                    0                247.9
# sub-NACC000531                                    0                309.5
# sub-NACC000920                                    0                157.3
# ...                                             ...                  ...
# sub-NACC999546                                    0                128.5
# sub-NACC999566                                    0                152.9
# sub-NACC999724                                    0                184.8
# sub-NACC999780                                    0                298.2
# sub-NACC999854                                    0                196.9
#
#                 volume_CC_Posterior  volume_CC_Mid_Posterior  \
# subj
# sub-NACC000034                760.4                    386.3
# sub-NACC000225                879.9                    455.5
# sub-NACC000511                915.4                    495.1
# sub-NACC000531               1242.5                    597.0
# sub-NACC000920               1061.3                    504.5
# ...                             ...                      ...
# sub-NACC999546               1312.6                    586.1
# sub-NACC999566                893.6                    499.9
# sub-NACC999724                892.6                    426.8
# sub-NACC999780               1116.3                    445.0
# sub-NACC999854               1125.8                    408.3
#
#                 volume_CC_Central  volume_CC_Mid_Anterior  volume_CC_Anterior
# subj
# sub-NACC000034              339.4                   324.4               710.5
# sub-NACC000225              387.5                   333.2               753.0
# sub-NACC000511              518.4                   492.3               896.5
# sub-NACC000531              552.0                   543.3              1086.6
# sub-NACC000920              376.8                   508.7               737.6
# ...                           ...                     ...                 ...
# sub-NACC999546              554.5                   543.0               881.1
# sub-NACC999566              388.1                   379.0               771.3
# sub-NACC999724              342.6                   463.3               696.7
# sub-NACC999780              379.4                   432.1               917.7
# sub-NACC999854              462.8                   449.4               842.7
#
# [5463 rows x 195 columns]

# %% [markdown]
# ## Filtering/changing Diagnoses

# %%
pd.DataFrame(*np.unique(nacc_df['diagnosis'], return_counts=True))
# Out:
#                                                       0
# 1729                           Alzheimer’s disease (AD)
# 13                                     Anxiety disorder
# 2                                      Bipolar disorder
# 2             Cognitive impairment due to alcohol abuse
# 8               Cognitive impairment due to medications
# 19    Cognitive impairment due to systemic disease o...
# 131   Cognitive impairment for other specified reaso...
# 2838                                            Control
# 11                      Corticobasal degeneration (CBD)
# 102                                          Depression
# 2            FTLD with motor neuron disease (e.g., ALS)
# 79                                          FTLD, other
# 120                             Lewy body disease (LBD)
# 207                                     Missing/unknown
# 56    Other neurologic, genetic, or infectious condi...
# 9                             Other psychiatric disease
# 9                            Prion disease (CJD, other)
# 9                  Progressive supranuclear palsy (PSP)
# 1                      Schizophrenia or other psychosis
# 14                         Traumatic brain injury (TBI)
# 102   Vascular brain injury or vascular dementia inc...

# %%
diagnosis_map = {'Alzheimer’s disease (AD)': 'AD',
                 'Vascular brain injury or vascular dementia including stroke': 'Other',
                 'Lewy body disease (LBD)': 'Other', 
                 'Control': 'Control', 
                 'Depression': 'Other',
                 'Missing/unknown': 'remove', ## <<---------- !
                 'Other neurologic, genetic, or infectious condition': 'Other',
                 'Cognitive impairment for other specified reasons (i.e., written-in values)': 'MCI',
                 'Prion disease (CJD, other)': 'Other', 
                 'FTLD, other': 'Other', 
                 'Anxiety disorder': 'Other',
                 'Corticobasal degeneration (CBD)': 'Other',
                 'Cognitive impairment due to medications': 'MCI',
                 'Other psychiatric disease': 'Other',
                 'Progressive supranuclear palsy (PSP)': 'Other',
                 'Cognitive impairment due to systemic disease or medical illness': 'MCI',
                 'Traumatic brain injury (TBI)': 'Other',
                 'Cognitive impairment due to alcohol abuse': 'MCI', 
                 'Bipolar disorder': 'Other',
                 'Schizophrenia or other psychosis': 'Other',
                 'FTLD with motor neuron disease (e.g., ALS)': 'Other'
                }
nacc_df.diagnosis = nacc_df.diagnosis.replace(diagnosis_map)
np.unique(nacc_df['diagnosis'], return_counts=True)
# Out:
# (array(['AD', 'Control', 'MCI', 'Other', 'remove'], dtype=object),
#  array([1729, 2838,  160,  529,  207]))

# %%
nacc_df = nacc_df.loc[nacc_df['diagnosis'] != 'remove', :]
np.unique(nacc_df['diagnosis'], return_counts=True)
# Out:
# (array(['AD', 'Control', 'MCI', 'Other'], dtype=object),
#  array([1729, 2838,  160,  529]))

# %% [markdown]
# ## Removing zeros/NaNs

# %%
# Slicing only features
sliced_df = nacc_df.loc[:, features_cort + features_vol + features_vol_extra]
print(sliced_df.shape)

sliced_df = sliced_df[~(sliced_df == 0).any(axis=1) & ~np.isnan(sliced_df).any(axis=1)]
print(sliced_df.shape)
# Out:
# (5256, 155)
# (5209, 155)

# %%
nacc_df = nacc_df.loc[sliced_df.index, :]
np.unique(nacc_df['diagnosis'], return_counts=True)
# Out:
# (array(['AD', 'Control', 'MCI', 'Other'], dtype=object),
#  array([1706, 2824,  160,  519]))

# %% [markdown]
# ## Visual checks on distributions

# %%
# print all output without truncating
pd.options.display.max_rows = 4000
for feats in [features_cort, features_vol, features_vol_extra]:
    tmp_df = nacc_df.loc[:, feats]
    
    # print mean and sd for each region
    print(tmp_df.apply(np.mean, 0))
    print(tmp_df.apply(np.std, 0))
    
    plt.figure(figsize=(20, 5))
    tmp_df.boxplot(rot=90)

    plt.show()
    plt.close()
# Out:
# thickness_bankssts_lh                    2.529054
# thickness_caudalanteriorcingulate_lh     2.467722
# thickness_caudalmiddlefrontal_lh         2.531954
# thickness_cuneus_lh                      2.074341
# thickness_entorhinal_lh                  3.150978
# thickness_fusiform_lh                    2.758255
# thickness_inferiorparietal_lh            2.514163
# thickness_inferiortemporal_lh            2.763136
# thickness_isthmuscingulate_lh            2.361849
# thickness_lateraloccipital_lh            2.285933
# thickness_lateralorbitofrontal_lh        2.696712
# thickness_lingual_lh                     2.169391
# thickness_medialorbitofrontal_lh         2.490856
# thickness_middletemporal_lh              2.745635
# thickness_parahippocampal_lh             2.704238
# thickness_paracentral_lh                 2.491393
# thickness_parsopercularis_lh             2.583434
# thickness_parsorbitalis_lh               2.717210
# thickness_parstriangularis_lh            2.510152
# thickness_pericalcarine_lh               1.917822
# thickness_postcentral_lh                 2.164720
# thickness_posteriorcingulate_lh          2.459012
# thickness_precentral_lh                  2.512506
# thickness_precuneus_lh                   2.478357
# thickness_rostralanteriorcingulate_lh    2.744180
# thickness_rostralmiddlefrontal_lh        2.414398
# thickness_superiorfrontal_lh             2.659543
# thickness_superiorparietal_lh            2.312244
# thickness_superiortemporal_lh            2.643991
# thickness_supramarginal_lh               2.561930
# thickness_frontalpole_lh                 2.675859
# thickness_temporalpole_lh                3.423290
# thickness_transversetemporal_lh          2.425205
# thickness_insula_lh                      2.946296
# thickness_bankssts_rh                    2.608659
# thickness_caudalanteriorcingulate_rh     2.430155
# thickness_caudalmiddlefrontal_rh         2.530325
# thickness_cuneus_rh                      2.050668
# thickness_entorhinal_rh                  3.229732
# thickness_fusiform_rh                    2.758361
# thickness_inferiorparietal_rh            2.510625
# thickness_inferiortemporal_rh            2.784613
# thickness_isthmuscingulate_rh            2.387748
# thickness_lateraloccipital_rh            2.327571
# thickness_lateralorbitofrontal_rh        2.706701
# thickness_lingual_rh                     2.169696
# thickness_medialorbitofrontal_rh         2.538397
# thickness_middletemporal_rh              2.794238
# thickness_parahippocampal_rh             2.636694
# thickness_paracentral_rh                 2.497173
# thickness_parsopercularis_rh             2.604122
# thickness_parsorbitalis_rh               2.752824
# thickness_parstriangularis_rh            2.535859
# thickness_pericalcarine_rh               1.905873
# thickness_postcentral_rh                 2.151549
# thickness_posteriorcingulate_rh          2.464257
# thickness_precentral_rh                  2.495996
# thickness_precuneus_rh                   2.479663
# thickness_rostralanteriorcingulate_rh    2.872090
# thickness_rostralmiddlefrontal_rh        2.436825
# thickness_superiorfrontal_rh             2.661145
# thickness_superiorparietal_rh            2.291899
# thickness_superiortemporal_rh            2.699166
# thickness_supramarginal_rh               2.554343
# thickness_frontalpole_rh                 2.676850
# thickness_temporalpole_rh                3.528390
# thickness_transversetemporal_rh          2.442991
# thickness_insula_rh                      2.958693
# dtype: float64
# thickness_bankssts_lh                    0.333989
# thickness_caudalanteriorcingulate_lh     0.479956
# thickness_caudalmiddlefrontal_lh         0.376481
# thickness_cuneus_lh                      0.284568
# thickness_entorhinal_lh                  0.541315
# thickness_fusiform_lh                    0.311606
# thickness_inferiorparietal_lh            0.328180
# thickness_inferiortemporal_lh            0.308042
# thickness_isthmuscingulate_lh            0.333822
# thickness_lateraloccipital_lh            0.276805
# thickness_lateralorbitofrontal_lh        0.314344
# thickness_lingual_lh                     0.256675
# thickness_medialorbitofrontal_lh         0.340214
# thickness_middletemporal_lh              0.353125
# thickness_parahippocampal_lh             0.459372
# thickness_paracentral_lh                 0.372561
# thickness_parsopercularis_lh             0.364035
# thickness_parsorbitalis_lh               0.402528
# thickness_parstriangularis_lh            0.335448
# thickness_pericalcarine_lh               0.251171
# thickness_postcentral_lh                 0.337633
# thickness_posteriorcingulate_lh          0.338252
# thickness_precentral_lh                  0.405384
# thickness_precuneus_lh                   0.323293
# thickness_rostralanteriorcingulate_lh    0.429319
# thickness_rostralmiddlefrontal_lh        0.329409
# thickness_superiorfrontal_lh             0.380663
# thickness_superiorparietal_lh            0.335216
# thickness_superiortemporal_lh            0.372554
# thickness_supramarginal_lh               0.350273
# thickness_frontalpole_lh                 0.517470
# thickness_temporalpole_lh                0.577649
# thickness_transversetemporal_lh          0.441236
# thickness_insula_lh                      0.376435
# thickness_bankssts_rh                    0.343238
# thickness_caudalanteriorcingulate_rh     0.412353
# thickness_caudalmiddlefrontal_rh         0.364871
# thickness_cuneus_rh                      0.289965
# thickness_entorhinal_rh                  0.556030
# thickness_fusiform_rh                    0.311251
# thickness_inferiorparietal_rh            0.327753
# thickness_inferiortemporal_rh            0.301363
# thickness_isthmuscingulate_rh            0.348238
# thickness_lateraloccipital_rh            0.271097
# thickness_lateralorbitofrontal_rh        0.320894
# thickness_lingual_rh                     0.277291
# thickness_medialorbitofrontal_rh         0.331225
# thickness_middletemporal_rh              0.348023
# thickness_parahippocampal_rh             0.414896
# thickness_paracentral_rh                 0.377795
# thickness_parsopercularis_rh             0.351261
# thickness_parsorbitalis_rh               0.378659
# thickness_parstriangularis_rh            0.324196
# thickness_pericalcarine_rh               0.270898
# thickness_postcentral_rh                 0.336001
# thickness_posteriorcingulate_rh          0.329654
# thickness_precentral_rh                  0.393820
# thickness_precuneus_rh                   0.326622
# thickness_rostralanteriorcingulate_rh    0.435631
# thickness_rostralmiddlefrontal_rh        0.309763
# thickness_superiorfrontal_rh             0.369590
# thickness_superiorparietal_rh            0.342240
# thickness_superiortemporal_rh            0.387215
# thickness_supramarginal_rh               0.352461
# thickness_frontalpole_rh                 0.503486
# thickness_temporalpole_rh                0.586843
# thickness_transversetemporal_rh          0.461128
# thickness_insula_rh                      0.372634
# dtype: float64
# volume_bankssts_lh                     2194.626032
# volume_caudalanteriorcingulate_lh      1467.693415
# volume_caudalmiddlefrontal_lh          5670.583221
# volume_cuneus_lh                       3083.162411
# volume_entorhinal_lh                   1859.347476
# volume_fusiform_lh                     8966.233634
# volume_inferiorparietal_lh            11027.493953
# volume_inferiortemporal_lh             9944.790171
# volume_isthmuscingulate_lh             2427.694375
# volume_lateraloccipital_lh            11699.639854
# volume_lateralorbitofrontal_lh         7188.893454
# volume_lingual_lh                      6429.973123
# volume_medialorbitofrontal_lh          4911.678057
# volume_middletemporal_lh               9560.383183
# volume_parahippocampal_lh              1922.033980
# volume_paracentral_lh                  3488.331158
# volume_parsopercularis_lh              4190.788059
# volume_parsorbitalis_lh                2214.246304
# volume_parstriangularis_lh             3350.435976
# volume_pericalcarine_lh                2224.707813
# volume_postcentral_lh                  9362.016318
# volume_posteriorcingulate_lh           2799.752736
# volume_precentral_lh                  12529.657708
# volume_precuneus_lh                    9006.442119
# volume_rostralanteriorcingulate_lh     2356.978883
# volume_rostralmiddlefrontal_lh        13729.349779
# volume_superiorfrontal_lh             20248.052793
# volume_superiorparietal_lh            12604.761758
# volume_superiortemporal_lh            11000.437128
# volume_supramarginal_lh               10401.754847
# volume_frontalpole_lh                   862.829718
# volume_temporalpole_lh                 2289.151085
# volume_transversetemporal_lh           1104.605107
# volume_insula_lh                       6881.454598
# volume_bankssts_rh                     2005.088117
# volume_caudalanteriorcingulate_rh      1764.585909
# volume_caudalmiddlefrontal_rh          5452.920522
# volume_cuneus_rh                       3246.893262
# volume_entorhinal_rh                   1790.074678
# volume_fusiform_rh                     8660.952582
# volume_inferiorparietal_rh            13290.817815
# volume_inferiortemporal_rh             9550.306009
# volume_isthmuscingulate_rh             2247.831830
# volume_lateraloccipital_rh            11852.875216
# volume_lateralorbitofrontal_rh         7121.897869
# volume_lingual_rh                      6741.496065
# volume_medialorbitofrontal_rh          5191.052985
# volume_middletemporal_rh              10520.815128
# volume_parahippocampal_rh              1817.259359
# volume_paracentral_rh                  3845.077942
# volume_parsopercularis_rh              3549.761183
# volume_parsorbitalis_rh                2600.110770
# volume_parstriangularis_rh             3872.287771
# volume_pericalcarine_rh                2440.438088
# volume_postcentral_rh                  8947.096564
# volume_posteriorcingulate_rh           2856.274909
# volume_precentral_rh                  12343.481090
# volume_precuneus_rh                    9322.076982
# volume_rostralanteriorcingulate_rh     1821.322711
# volume_rostralmiddlefrontal_rh        14337.859090
# volume_superiorfrontal_rh             19415.574390
# volume_superiorparietal_rh            12299.807449
# volume_superiortemporal_rh            10476.561912
# volume_supramarginal_rh                9334.908428
# volume_frontalpole_rh                  1043.141102
# volume_temporalpole_rh                 2361.900749
# volume_transversetemporal_rh            873.915915
# volume_insula_rh                       6842.868497
# dtype: float64
# volume_bankssts_lh                     528.955213
# volume_caudalanteriorcingulate_lh      567.761197
# volume_caudalmiddlefrontal_lh         1399.804310
# volume_cuneus_lh                       774.316794
# volume_entorhinal_lh                   617.775458
# volume_fusiform_lh                    1781.445239
# volume_inferiorparietal_lh            2483.048072
# volume_inferiortemporal_lh            2193.180983
# volume_isthmuscingulate_lh             696.056303
# volume_lateraloccipital_lh            2427.799241
# volume_lateralorbitofrontal_lh        1294.472991
# volume_lingual_lh                     1392.249716
# volume_medialorbitofrontal_lh          967.512339
# volume_middletemporal_lh              2244.808699
# volume_parahippocampal_lh              509.780282
# volume_paracentral_lh                  715.274521
# volume_parsopercularis_lh             1007.108672
# volume_parsorbitalis_lh                496.965751
# volume_parstriangularis_lh             784.582483
# volume_pericalcarine_lh                581.229042
# volume_postcentral_lh                 2047.151455
# volume_posteriorcingulate_lh           710.467700
# volume_precentral_lh                  2620.974007
# volume_precuneus_lh                   1884.040892
# volume_rostralanteriorcingulate_lh     704.238207
# volume_rostralmiddlefrontal_lh        3003.516652
# volume_superiorfrontal_lh             4033.120247
# volume_superiorparietal_lh            2780.076778
# volume_superiortemporal_lh            2351.048056
# volume_supramarginal_lh               2387.099664
# volume_frontalpole_lh                  249.752097
# volume_temporalpole_lh                 620.368022
# volume_transversetemporal_lh           298.905554
# volume_insula_lh                      1375.352379
# volume_bankssts_rh                     468.684985
# volume_caudalanteriorcingulate_rh      576.723888
# volume_caudalmiddlefrontal_rh         1370.268158
# volume_cuneus_rh                       791.699621
# volume_entorhinal_rh                   591.174453
# volume_fusiform_rh                    1806.845087
# volume_inferiorparietal_rh            3014.990730
# volume_inferiortemporal_rh            2075.814388
# volume_isthmuscingulate_rh             596.907303
# volume_lateraloccipital_rh            2500.259461
# volume_lateralorbitofrontal_rh        1280.986903
# volume_lingual_rh                     1486.852654
# volume_medialorbitofrontal_rh         1165.220346
# volume_middletemporal_rh              2358.927931
# volume_parahippocampal_rh              516.934001
# volume_paracentral_rh                  797.824688
# volume_parsopercularis_rh              848.814986
# volume_parsorbitalis_rh                574.221947
# volume_parstriangularis_rh             916.180221
# volume_pericalcarine_rh                629.692375
# volume_postcentral_rh                 1967.963262
# volume_posteriorcingulate_rh           724.627681
# volume_precentral_rh                  2602.600679
# volume_precuneus_rh                   1935.762254
# volume_rostralanteriorcingulate_rh     591.001667
# volume_rostralmiddlefrontal_rh        3162.496075
# volume_superiorfrontal_rh             3914.476990
# volume_superiorparietal_rh            2734.213138
# volume_superiortemporal_rh            2211.768804
# volume_supramarginal_rh               2086.517179
# volume_frontalpole_rh                  296.282313
# volume_temporalpole_rh                 610.666241
# volume_transversetemporal_rh           236.103753
# volume_insula_rh                      1355.176841
# dtype: float64
# volume_Left-Cerebellum-White-Matter     13272.130985
# volume_Left-Cerebellum-Cortex           49928.648551
# volume_Left-Thalamus-Proper              6533.845229
# volume_Left-Caudate                      3273.337109
# volume_Left-Putamen                      4108.326185
# volume_Left-Pallidum                     1795.507890
# volume_Brain-Stem                       20081.665444
# volume_Left-Hippocampus                  3449.629468
# volume_Left-Amygdala                     1288.820407
# volume_Left-Accumbens-area                399.642753
# volume_Right-Cerebellum-White-Matter    12751.221712
# volume_Right-Cerebellum-Cortex          50371.169668
# volume_Right-Thalamus-Proper             6389.242772
# volume_Right-Caudate                     3370.412440
# volume_Right-Putamen                     4120.095009
# volume_Right-Pallidum                    1762.782780
# volume_Right-Hippocampus                 3561.387176
# volume_Right-Amygdala                    1478.904166
# volume_Right-Accumbens-area               422.061336
# dtype: float64
# volume_Left-Cerebellum-White-Matter     2526.692536
# volume_Left-Cerebellum-Cortex           6665.970595
# volume_Left-Thalamus-Proper             1000.714021
# volume_Left-Caudate                      639.691334
# volume_Left-Putamen                      693.293639
# volume_Left-Pallidum                     297.188143
# volume_Brain-Stem                       2563.908991
# volume_Left-Hippocampus                  597.332002
# volume_Left-Amygdala                     296.171951
# volume_Left-Accumbens-area               128.572267
# volume_Right-Cerebellum-White-Matter    2450.378947
# volume_Right-Cerebellum-Cortex          6866.182105
# volume_Right-Thalamus-Proper             975.708706
# volume_Right-Caudate                     650.629325
# volume_Right-Putamen                     697.431681
# volume_Right-Pallidum                    298.275939
# volume_Right-Hippocampus                 626.403891
# volume_Right-Amygdala                    311.974478
# volume_Right-Accumbens-area              111.870782
# dtype: float64

# %%
nacc_df.to_csv('nacc_raw_filtered.csv')

# %% [markdown]
# ## Processing data as with ADNI

# %%
import statsmodels.api as smf

from sklearn.preprocessing import StandardScaler
import joblib 

def calculate_residuals(data, columns, name_regress):
    for c in columns:
        lin_model = smf.load(f'../regress_models/{name_regress}_{c}.pkl')
        
        data[c] = data[c] - lin_model.predict(data)

# %%
nacc_df
# Out:
#                diagnosis  session_diff  age  gender          eTIV  nacmmse  \
# subj
# sub-NACC000034        AD           291   81  Female  1.428260e+06      NaN
# sub-NACC000225     Other             0   77    Male  1.461785e+06     24.0
# sub-NACC000511        AD           335   77  Female  1.584573e+06      NaN
# sub-NACC000531     Other           334   62    Male  1.824642e+06      NaN
# sub-NACC000920   Control           572   64  Female  1.449166e+06      NaN
# ...                  ...           ...  ...     ...           ...      ...
# sub-NACC999346        AD          1021   69    Male  1.669576e+06      NaN
# sub-NACC999546   Control           420   78    Male  1.478121e+06      NaN
# sub-NACC999566     Other            30   53  Female  1.197214e+06      NaN
# sub-NACC999724     Other            26   50    Male  1.348062e+06      NaN
# sub-NACC999854   Control           271   80  Female  1.282693e+06      NaN
#
#                 digif  digib  animals  trialsb  ...  \
# subj                                            ...
# sub-NACC000034    NaN    NaN      NaN      NaN  ...
# sub-NACC000225    4.0    5.0     19.0      NaN  ...
# sub-NACC000511    NaN    NaN      NaN      NaN  ...
# sub-NACC000531    NaN    NaN      NaN      NaN  ...
# sub-NACC000920    NaN    NaN      NaN      NaN  ...
# ...               ...    ...      ...      ...  ...
# sub-NACC999346    NaN    NaN      NaN      NaN  ...
# sub-NACC999546    NaN    NaN      NaN      NaN  ...
# sub-NACC999566    NaN    NaN      NaN      NaN  ...
# sub-NACC999724    NaN    NaN      NaN      NaN  ...
# sub-NACC999854    NaN    NaN      NaN      NaN  ...
#
#                 volume_Right-WM-hypointensities  \
# subj
# sub-NACC000034                                0
# sub-NACC000225                                0
# sub-NACC000511                                0
# sub-NACC000531                                0
# sub-NACC000920                                0
# ...                                         ...
# sub-NACC999346                                0
# sub-NACC999546                                0
# sub-NACC999566                                0
# sub-NACC999724                                0
# sub-NACC999854                                0
#
#                 volume_non-WM-hypointensities  \
# subj
# sub-NACC000034                            0.0
# sub-NACC000225                            0.0
# sub-NACC000511                            0.0
# sub-NACC000531                            0.0
# sub-NACC000920                            0.0
# ...                                       ...
# sub-NACC999346                            0.0
# sub-NACC999546                            0.0
# sub-NACC999566                            0.0
# sub-NACC999724                            0.0
# sub-NACC999854                            0.0
#
#                 volume_Left-non-WM-hypointensities  \
# subj
# sub-NACC000034                                   0
# sub-NACC000225                                   0
# sub-NACC000511                                   0
# sub-NACC000531                                   0
# sub-NACC000920                                   0
# ...                                            ...
# sub-NACC999346                                   0
# sub-NACC999546                                   0
# sub-NACC999566                                   0
# sub-NACC999724                                   0
# sub-NACC999854                                   0
#
#                 volume_Right-non-WM-hypointensities  volume_Optic-Chiasm  \
# subj
# sub-NACC000034                                    0                232.3
# sub-NACC000225                                    0                183.9
# sub-NACC000511                                    0                247.9
# sub-NACC000531                                    0                309.5
# sub-NACC000920                                    0                157.3
# ...                                             ...                  ...
# sub-NACC999346                                    0                243.5
# sub-NACC999546                                    0                128.5
# sub-NACC999566                                    0                152.9
# sub-NACC999724                                    0                184.8
# sub-NACC999854                                    0                196.9
#
#                 volume_CC_Posterior  volume_CC_Mid_Posterior  \
# subj
# sub-NACC000034                760.4                    386.3
# sub-NACC000225                879.9                    455.5
# sub-NACC000511                915.4                    495.1
# sub-NACC000531               1242.5                    597.0
# sub-NACC000920               1061.3                    504.5
# ...                             ...                      ...
# sub-NACC999346               1208.2                    498.5
# sub-NACC999546               1312.6                    586.1
# sub-NACC999566                893.6                    499.9
# sub-NACC999724                892.6                    426.8
# sub-NACC999854               1125.8                    408.3
#
#                 volume_CC_Central  volume_CC_Mid_Anterior  volume_CC_Anterior
# subj
# sub-NACC000034              339.4                   324.4               710.5
# sub-NACC000225              387.5                   333.2               753.0
# sub-NACC000511              518.4                   492.3               896.5
# sub-NACC000531              552.0                   543.3              1086.6
# sub-NACC000920              376.8                   508.7               737.6
# ...                           ...                     ...                 ...
# sub-NACC999346              445.0                   365.6               872.3
# sub-NACC999546              554.5                   543.0               881.1
# sub-NACC999566              388.1                   379.0               771.3
# sub-NACC999724              342.6                   463.3               696.7
# sub-NACC999854              462.8                   449.4               842.7
#
# [5209 rows x 195 columns]

# %%
nacc_df = pd.read_csv('nacc_raw_filtered.csv', index_col=0)

# %%
# Calculate residuals for NACC data (load model and calculate from previously fitted adni data)
calculate_residuals(data=nacc_df, columns=features_cort, name_regress='adni')
calculate_residuals(data=nacc_df, columns=features_vol+features_vol_extra, name_regress='adni')

# %%
scaler = joblib.load('adni_train_scaler.joblib')
#scaler.mean_

# %%
nacc_df = nacc_df.loc[:, features_cort + features_vol + features_vol_extra]

# %%
nacc_scaled = pd.DataFrame(scaler.transform(nacc_df), columns=nacc_df.columns, index=nacc_df.index)

# %%
for feats in [features_cort, features_vol, features_vol_extra]:
    tmp_df = nacc_scaled.loc[:, feats]
    
    plt.figure(figsize=(20, 5))
    tmp_df.boxplot(rot=90)

    plt.show()
    plt.close()

# %%
nacc_scaled.to_csv('nacc_scaled_corrected.csv')
